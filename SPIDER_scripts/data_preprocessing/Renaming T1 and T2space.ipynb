# %%
import os
import shutil

# --- Configuration ---
images_folder = 'C:/ADLM/Datasets/SPIDER_FULL_FINAL/10159290/renaming/T1_images_reoriented'  # <--- IMPORTANT: Change this to your actual image folder path
masks_folder = 'C:/ADLM/Datasets/SPIDER_FULL_FINAL/10159290/renaming/T1_masks_reoriented_relabeled'    # <--- IMPORTANT: Change this to your actual mask folder path
start_new_prefix = 501 # This will be the starting number for the '901', '902', etc. sequence

# --- Function to extract base name and extension ---
def split_filename(filename):
    base_name = os.path.basename(filename)
    name_without_ext, ext = os.path.splitext(base_name)
    if name_without_ext.endswith('.nii'): # Handle .nii.gz
        name_without_ext, nifti_ext = os.path.splitext(name_without_ext)
        ext = nifti_ext + ext
    return name_without_ext, ext

# --- Main Renaming Logic ---
def rename_files_v2(images_folder, masks_folder, start_new_prefix):
    image_files = sorted([f for f in os.listdir(images_folder) if f.endswith('.nii.gz')])
    mask_files = sorted([f for f in os.listdir(masks_folder) if f.endswith('.nii.gz')])

    # Create dictionaries for faster lookup
    images_map = {split_filename(f)[0]: f for f in image_files}
    masks_map = {split_filename(f)[0]: f for f in mask_files}

    # Extract and sort unique original prefixes (e.g., 107, 110, 118)
    original_prefixes = sorted(list(set(split_filename(f)[0].split('_')[0] for f in image_files)))

    # Map original prefixes to new sequential prefixes (e.g., 107 -> 901, 110 -> 902)
    prefix_mapping = {}
    current_new_prefix = start_new_prefix
    for original_prefix in original_prefixes:
        prefix_mapping[original_prefix] = current_new_prefix
        current_new_prefix += 1

    renamed_count = 0

    print(f"Starting file renaming process (Version 2)...")
    print(f"Original Prefix Mappings: {prefix_mapping}")

    # Process files based on their original prefix, then suffix
    for original_prefix in sorted(prefix_mapping.keys()):
        new_prefix = prefix_mapping[original_prefix]
        new_suffix_counter = 1 # Reset suffix for each new prefix

        # Find all files belonging to this original_prefix
        files_for_this_prefix = sorted([
            base_name for base_name in images_map.keys()
            if base_name.startswith(f"{original_prefix}_")
        ])

        for old_base_name in files_for_this_prefix:
            if old_base_name in masks_map:
                old_image_full_path = os.path.join(images_folder, images_map[old_base_name])
                old_mask_full_path = os.path.join(masks_folder, masks_map[old_base_name])

                # Generate new filename parts
                new_prefix_str = str(new_prefix)
                new_suffix_str = f"{new_suffix_counter:04d}" # Formats to 0001, 0002, etc.

                new_base_name = f"{new_prefix_str}_{new_suffix_str}"
                
                # Get the original extension (e.g., .nii.gz)
                _, ext = split_filename(images_map[old_base_name])

                new_image_full_path = os.path.join(images_folder, new_base_name + ext)
                new_mask_full_path = os.path.join(masks_folder, new_base_name + ext)

                try:
                    # Rename image
                    shutil.move(old_image_full_path, new_image_full_path)
                    print(f"Renamed image: {os.path.basename(old_image_full_path)} -> {os.path.basename(new_image_full_path)}")

                    # Rename mask
                    shutil.move(old_mask_full_path, new_mask_full_path)
                    print(f"Renamed mask:  {os.path.basename(old_mask_full_path)} -> {os.path.basename(new_mask_full_path)}")
                    
                    new_suffix_counter += 1
                    renamed_count += 1

                except Exception as e:
                    print(f"Error renaming files for base name {old_base_name}: {e}")
            else:
                print(f"Warning: No corresponding mask found for image: {images_map[old_base_name]} (Skipping)")

    print(f"\nFinished renaming. Renamed {renamed_count} pairs of files.")

# --- Run the renaming function ---
if __name__ == "__main__":
    # !!! IMPORTANT: Before running, uncomment the line below and replace with your actual paths.
    # Be very careful and test on a copy of your data first!
    rename_files_v2(images_folder, masks_folder, start_new_prefix)
    print("WARNING: The renaming function is commented out by default. Please read the script, set your paths, and uncomment 'rename_files_v2(...)' to run.")
    print("It is highly recommended to test this script on a *copy* of your data first to prevent accidental data loss.")
# Out:
# Starting file renaming process (Version 2)...
# Original Prefix Mappings: {'1': 501, '10': 502, '100': 503, '101': 504, '104': 505, '105': 506, '106': 507, '107': 508, '108': 509, '109': 510, '11': 511, '110': 512, '112': 513, '113': 514, '115': 515, '116': 516, '117': 517, '118': 518, '12': 519, '121': 520, '122': 521, '125': 522, '126': 523, '127': 524, '129': 525, '13': 526, '130': 527, '131': 528, '132': 529, '133': 530, '136': 531, '137': 532, '138': 533, '140': 534, '142': 535, '143': 536, '144': 537, '145': 538, '146': 539, '149': 540, '15': 541, '152': 542, '154': 543, '155': 544, '156': 545, '16': 546, '160': 547, '161': 548, '162': 549, '163': 550, '165': 551, '166': 552, '167': 553, '168': 554, '169': 555, '17': 556, '170': 557, '171': 558, '172': 559, '173': 560, '174': 561, '175': 562, '177': 563, '179': 564, '18': 565, '180': 566, '181': 567, '182': 568, '184': 569, '185': 570, '186': 571, '187': 572, '188': 573, '189': 574, '19': 575, '190': 576, '191': 577, '192': 578, '193': 579, '195': 580, '196': 581, '198': 582, '2': 583, '200': 584, '202': 585, '203': 586, '204': 587, '205': 588, '207': 589, '209': 590, '210': 591, '212': 592, '213': 593, '214': 594, '215': 595, '217': 596, '218': 597, '219': 598, '22': 599, '220': 600, '221': 601, '222': 602, '223': 603, '224': 604, '225': 605, '226': 606, '227': 607, '228': 608, '229': 609, '23': 610, '231': 611, '232': 612, '233': 613, '234': 614, '236': 615, '237': 616, '239': 617, '24': 618, '241': 619, '242': 620, '243': 621, '244': 622, '245': 623, '249': 624, '25': 625, '250': 626, '251': 627, '252': 628, '253': 629, '254': 630, '255': 631, '256': 632, '257': 633, '28': 634, '29': 635, '3': 636, '30': 637, '31': 638, '32': 639, '33': 640, '34': 641, '35': 642, '36': 643, '37': 644, '38': 645, '39': 646, '4': 647, '40': 648, '44': 649, '45': 650, '47': 651, '48': 652, '5': 653, '50': 654, '51': 655, '52': 656, '53': 657, '55': 658, '56': 659, '57': 660, '58': 661, '59': 662, '60': 663, '61': 664, '62': 665, '63': 666, '64': 667, '65': 668, '66': 669, '67': 670, '68': 671, '69': 672, '7': 673, '71': 674, '72': 675, '73': 676, '74': 677, '75': 678, '77': 679, '78': 680, '8': 681, '80': 682, '81': 683, '82': 684, '83': 685, '85': 686, '86': 687, '87': 688, '88': 689, '9': 690, '90': 691, '93': 692, '94': 693, '95': 694, '96': 695, '98': 696}
# Renamed image: 1_0000.nii.gz -> 501_0001.nii.gz
# Renamed mask:  1_0000.nii.gz -> 501_0001.nii.gz
# Renamed image: 10_0000.nii.gz -> 502_0001.nii.gz
# Renamed mask:  10_0000.nii.gz -> 502_0001.nii.gz
# Renamed image: 100_0000.nii.gz -> 503_0001.nii.gz
# Renamed mask:  100_0000.nii.gz -> 503_0001.nii.gz
# Renamed image: 101_0000.nii.gz -> 504_0001.nii.gz
# Renamed mask:  101_0000.nii.gz -> 504_0001.nii.gz
# Renamed image: 104_0000.nii.gz -> 505_0001.nii.gz
# Renamed mask:  104_0000.nii.gz -> 505_0001.nii.gz
# Renamed image: 105_0000.nii.gz -> 506_0001.nii.gz
# Renamed mask:  105_0000.nii.gz -> 506_0001.nii.gz
# Renamed image: 106_0000.nii.gz -> 507_0001.nii.gz
# Renamed mask:  106_0000.nii.gz -> 507_0001.nii.gz
# Renamed image: 107_0000.nii.gz -> 508_0001.nii.gz
# Renamed mask:  107_0000.nii.gz -> 508_0001.nii.gz
# Renamed image: 108_0000.nii.gz -> 509_0001.nii.gz
# Renamed mask:  108_0000.nii.gz -> 509_0001.nii.gz
# Renamed image: 109_0000.nii.gz -> 510_0001.nii.gz
# Renamed mask:  109_0000.nii.gz -> 510_0001.nii.gz
# Renamed image: 11_0000.nii.gz -> 511_0001.nii.gz
# Renamed mask:  11_0000.nii.gz -> 511_0001.nii.gz
# Renamed image: 110_0000.nii.gz -> 512_0001.nii.gz
# Renamed mask:  110_0000.nii.gz -> 512_0001.nii.gz
# Renamed image: 112_0000.nii.gz -> 513_0001.nii.gz
# Renamed mask:  112_0000.nii.gz -> 513_0001.nii.gz
# Renamed image: 113_0000.nii.gz -> 514_0001.nii.gz
# Renamed mask:  113_0000.nii.gz -> 514_0001.nii.gz
# Renamed image: 115_0000.nii.gz -> 515_0001.nii.gz
# Renamed mask:  115_0000.nii.gz -> 515_0001.nii.gz
# Renamed image: 116_0000.nii.gz -> 516_0001.nii.gz
# Renamed mask:  116_0000.nii.gz -> 516_0001.nii.gz
# Renamed image: 117_0000.nii.gz -> 517_0001.nii.gz
# Renamed mask:  117_0000.nii.gz -> 517_0001.nii.gz
# Renamed image: 118_0000.nii.gz -> 518_0001.nii.gz
# Renamed mask:  118_0000.nii.gz -> 518_0001.nii.gz
# Renamed image: 12_0000.nii.gz -> 519_0001.nii.gz
# Renamed mask:  12_0000.nii.gz -> 519_0001.nii.gz
# Renamed image: 121_0000.nii.gz -> 520_0001.nii.gz
# Renamed mask:  121_0000.nii.gz -> 520_0001.nii.gz
# Renamed image: 122_0000.nii.gz -> 521_0001.nii.gz
# Renamed mask:  122_0000.nii.gz -> 521_0001.nii.gz
# Renamed image: 125_0000.nii.gz -> 522_0001.nii.gz
# Renamed mask:  125_0000.nii.gz -> 522_0001.nii.gz
# Renamed image: 126_0000.nii.gz -> 523_0001.nii.gz
# Renamed mask:  126_0000.nii.gz -> 523_0001.nii.gz
# Renamed image: 127_0000.nii.gz -> 524_0001.nii.gz
# Renamed mask:  127_0000.nii.gz -> 524_0001.nii.gz
# Renamed image: 129_0000.nii.gz -> 525_0001.nii.gz
# Renamed mask:  129_0000.nii.gz -> 525_0001.nii.gz
# Renamed image: 13_0000.nii.gz -> 526_0001.nii.gz
# Renamed mask:  13_0000.nii.gz -> 526_0001.nii.gz
# Renamed image: 130_0000.nii.gz -> 527_0001.nii.gz
# Renamed mask:  130_0000.nii.gz -> 527_0001.nii.gz
# Renamed image: 131_0000.nii.gz -> 528_0001.nii.gz
# Renamed mask:  131_0000.nii.gz -> 528_0001.nii.gz
# Renamed image: 132_0000.nii.gz -> 529_0001.nii.gz
# Renamed mask:  132_0000.nii.gz -> 529_0001.nii.gz
# Renamed image: 133_0000.nii.gz -> 530_0001.nii.gz
# Renamed mask:  133_0000.nii.gz -> 530_0001.nii.gz
# Renamed image: 136_0000.nii.gz -> 531_0001.nii.gz
# Renamed mask:  136_0000.nii.gz -> 531_0001.nii.gz
# Renamed image: 137_0000.nii.gz -> 532_0001.nii.gz
# Renamed mask:  137_0000.nii.gz -> 532_0001.nii.gz
# Renamed image: 138_0000.nii.gz -> 533_0001.nii.gz
# Renamed mask:  138_0000.nii.gz -> 533_0001.nii.gz
# Renamed image: 140_0000.nii.gz -> 534_0001.nii.gz
# Renamed mask:  140_0000.nii.gz -> 534_0001.nii.gz
# Renamed image: 142_0000.nii.gz -> 535_0001.nii.gz
# Renamed mask:  142_0000.nii.gz -> 535_0001.nii.gz
# Renamed image: 143_0000.nii.gz -> 536_0001.nii.gz
# Renamed mask:  143_0000.nii.gz -> 536_0001.nii.gz
# Renamed image: 144_0000.nii.gz -> 537_0001.nii.gz
# Renamed mask:  144_0000.nii.gz -> 537_0001.nii.gz
# Renamed image: 145_0000.nii.gz -> 538_0001.nii.gz
# Renamed mask:  145_0000.nii.gz -> 538_0001.nii.gz
# Renamed image: 146_0000.nii.gz -> 539_0001.nii.gz
# Renamed mask:  146_0000.nii.gz -> 539_0001.nii.gz
# Renamed image: 149_0000.nii.gz -> 540_0001.nii.gz
# Renamed mask:  149_0000.nii.gz -> 540_0001.nii.gz
# Renamed image: 15_0000.nii.gz -> 541_0001.nii.gz
# Renamed mask:  15_0000.nii.gz -> 541_0001.nii.gz
# Renamed image: 152_0000.nii.gz -> 542_0001.nii.gz
# Renamed mask:  152_0000.nii.gz -> 542_0001.nii.gz
# Renamed image: 154_0000.nii.gz -> 543_0001.nii.gz
# Renamed mask:  154_0000.nii.gz -> 543_0001.nii.gz
# Renamed image: 155_0000.nii.gz -> 544_0001.nii.gz
# Renamed mask:  155_0000.nii.gz -> 544_0001.nii.gz
# Renamed image: 156_0000.nii.gz -> 545_0001.nii.gz
# Renamed mask:  156_0000.nii.gz -> 545_0001.nii.gz
# Renamed image: 16_0000.nii.gz -> 546_0001.nii.gz
# Renamed mask:  16_0000.nii.gz -> 546_0001.nii.gz
# Renamed image: 160_0000.nii.gz -> 547_0001.nii.gz
# Renamed mask:  160_0000.nii.gz -> 547_0001.nii.gz
# Renamed image: 161_0000.nii.gz -> 548_0001.nii.gz
# Renamed mask:  161_0000.nii.gz -> 548_0001.nii.gz
# Renamed image: 162_0000.nii.gz -> 549_0001.nii.gz
# Renamed mask:  162_0000.nii.gz -> 549_0001.nii.gz
# Renamed image: 163_0000.nii.gz -> 550_0001.nii.gz
# Renamed mask:  163_0000.nii.gz -> 550_0001.nii.gz
# Renamed image: 165_0000.nii.gz -> 551_0001.nii.gz
# Renamed mask:  165_0000.nii.gz -> 551_0001.nii.gz
# Renamed image: 166_0000.nii.gz -> 552_0001.nii.gz
# Renamed mask:  166_0000.nii.gz -> 552_0001.nii.gz
# Renamed image: 167_0000.nii.gz -> 553_0001.nii.gz
# Renamed mask:  167_0000.nii.gz -> 553_0001.nii.gz
# Renamed image: 168_0000.nii.gz -> 554_0001.nii.gz
# Renamed mask:  168_0000.nii.gz -> 554_0001.nii.gz
# Renamed image: 169_0000.nii.gz -> 555_0001.nii.gz
# Renamed mask:  169_0000.nii.gz -> 555_0001.nii.gz
# Renamed image: 17_0000.nii.gz -> 556_0001.nii.gz
# Renamed mask:  17_0000.nii.gz -> 556_0001.nii.gz
# Renamed image: 170_0000.nii.gz -> 557_0001.nii.gz
# Renamed mask:  170_0000.nii.gz -> 557_0001.nii.gz
# Renamed image: 171_0000.nii.gz -> 558_0001.nii.gz
# Renamed mask:  171_0000.nii.gz -> 558_0001.nii.gz
# Renamed image: 172_0000.nii.gz -> 559_0001.nii.gz
# Renamed mask:  172_0000.nii.gz -> 559_0001.nii.gz
# Renamed image: 173_0000.nii.gz -> 560_0001.nii.gz
# Renamed mask:  173_0000.nii.gz -> 560_0001.nii.gz
# Renamed image: 174_0000.nii.gz -> 561_0001.nii.gz
# Renamed mask:  174_0000.nii.gz -> 561_0001.nii.gz
# Renamed image: 175_0000.nii.gz -> 562_0001.nii.gz
# Renamed mask:  175_0000.nii.gz -> 562_0001.nii.gz
# Renamed image: 177_0000.nii.gz -> 563_0001.nii.gz
# Renamed mask:  177_0000.nii.gz -> 563_0001.nii.gz
# Renamed image: 179_0000.nii.gz -> 564_0001.nii.gz
# Renamed mask:  179_0000.nii.gz -> 564_0001.nii.gz
# Renamed image: 18_0000.nii.gz -> 565_0001.nii.gz
# Renamed mask:  18_0000.nii.gz -> 565_0001.nii.gz
# Renamed image: 180_0000.nii.gz -> 566_0001.nii.gz
# Renamed mask:  180_0000.nii.gz -> 566_0001.nii.gz
# Renamed image: 181_0000.nii.gz -> 567_0001.nii.gz
# Renamed mask:  181_0000.nii.gz -> 567_0001.nii.gz
# Renamed image: 182_0000.nii.gz -> 568_0001.nii.gz
# Renamed mask:  182_0000.nii.gz -> 568_0001.nii.gz
# Renamed image: 184_0000.nii.gz -> 569_0001.nii.gz
# Renamed mask:  184_0000.nii.gz -> 569_0001.nii.gz
# Renamed image: 185_0000.nii.gz -> 570_0001.nii.gz
# Renamed mask:  185_0000.nii.gz -> 570_0001.nii.gz
# Renamed image: 186_0000.nii.gz -> 571_0001.nii.gz
# Renamed mask:  186_0000.nii.gz -> 571_0001.nii.gz
# Renamed image: 187_0000.nii.gz -> 572_0001.nii.gz
# Renamed mask:  187_0000.nii.gz -> 572_0001.nii.gz
# Renamed image: 188_0000.nii.gz -> 573_0001.nii.gz
# Renamed mask:  188_0000.nii.gz -> 573_0001.nii.gz
# Renamed image: 189_0000.nii.gz -> 574_0001.nii.gz
# Renamed mask:  189_0000.nii.gz -> 574_0001.nii.gz
# Renamed image: 19_0000.nii.gz -> 575_0001.nii.gz
# Renamed mask:  19_0000.nii.gz -> 575_0001.nii.gz
# Renamed image: 190_0000.nii.gz -> 576_0001.nii.gz
# Renamed mask:  190_0000.nii.gz -> 576_0001.nii.gz
# Renamed image: 191_0000.nii.gz -> 577_0001.nii.gz
# Renamed mask:  191_0000.nii.gz -> 577_0001.nii.gz
# Renamed image: 192_0000.nii.gz -> 578_0001.nii.gz
# Renamed mask:  192_0000.nii.gz -> 578_0001.nii.gz
# Renamed image: 193_0000.nii.gz -> 579_0001.nii.gz
# Renamed mask:  193_0000.nii.gz -> 579_0001.nii.gz
# Renamed image: 195_0000.nii.gz -> 580_0001.nii.gz
# Renamed mask:  195_0000.nii.gz -> 580_0001.nii.gz
# Renamed image: 196_0000.nii.gz -> 581_0001.nii.gz
# Renamed mask:  196_0000.nii.gz -> 581_0001.nii.gz
# Renamed image: 198_0000.nii.gz -> 582_0001.nii.gz
# Renamed mask:  198_0000.nii.gz -> 582_0001.nii.gz
# Renamed image: 2_0000.nii.gz -> 583_0001.nii.gz
# Renamed mask:  2_0000.nii.gz -> 583_0001.nii.gz
# Renamed image: 200_0000.nii.gz -> 584_0001.nii.gz
# Renamed mask:  200_0000.nii.gz -> 584_0001.nii.gz
# Renamed image: 202_0000.nii.gz -> 585_0001.nii.gz
# Renamed mask:  202_0000.nii.gz -> 585_0001.nii.gz
# Renamed image: 203_0000.nii.gz -> 586_0001.nii.gz
# Renamed mask:  203_0000.nii.gz -> 586_0001.nii.gz
# Renamed image: 204_0000.nii.gz -> 587_0001.nii.gz
# Renamed mask:  204_0000.nii.gz -> 587_0001.nii.gz
# Renamed image: 205_0000.nii.gz -> 588_0001.nii.gz
# Renamed mask:  205_0000.nii.gz -> 588_0001.nii.gz
# Renamed image: 207_0000.nii.gz -> 589_0001.nii.gz
# Renamed mask:  207_0000.nii.gz -> 589_0001.nii.gz
# Renamed image: 209_0000.nii.gz -> 590_0001.nii.gz
# Renamed mask:  209_0000.nii.gz -> 590_0001.nii.gz
# Renamed image: 210_0000.nii.gz -> 591_0001.nii.gz
# Renamed mask:  210_0000.nii.gz -> 591_0001.nii.gz
# Renamed image: 212_0000.nii.gz -> 592_0001.nii.gz
# Renamed mask:  212_0000.nii.gz -> 592_0001.nii.gz
# Renamed image: 213_0000.nii.gz -> 593_0001.nii.gz
# Renamed mask:  213_0000.nii.gz -> 593_0001.nii.gz
# Renamed image: 214_0000.nii.gz -> 594_0001.nii.gz
# Renamed mask:  214_0000.nii.gz -> 594_0001.nii.gz
# Renamed image: 215_0000.nii.gz -> 595_0001.nii.gz
# Renamed mask:  215_0000.nii.gz -> 595_0001.nii.gz
# Renamed image: 217_0000.nii.gz -> 596_0001.nii.gz
# Renamed mask:  217_0000.nii.gz -> 596_0001.nii.gz
# Renamed image: 218_0000.nii.gz -> 597_0001.nii.gz
# Renamed mask:  218_0000.nii.gz -> 597_0001.nii.gz
# Renamed image: 219_0000.nii.gz -> 598_0001.nii.gz
# Renamed mask:  219_0000.nii.gz -> 598_0001.nii.gz
# Renamed image: 22_0000.nii.gz -> 599_0001.nii.gz
# Renamed mask:  22_0000.nii.gz -> 599_0001.nii.gz
# Renamed image: 220_0000.nii.gz -> 600_0001.nii.gz
# Renamed mask:  220_0000.nii.gz -> 600_0001.nii.gz
# Renamed image: 221_0000.nii.gz -> 601_0001.nii.gz
# Renamed mask:  221_0000.nii.gz -> 601_0001.nii.gz
# Renamed image: 222_0000.nii.gz -> 602_0001.nii.gz
# Renamed mask:  222_0000.nii.gz -> 602_0001.nii.gz
# Renamed image: 223_0000.nii.gz -> 603_0001.nii.gz
# Renamed mask:  223_0000.nii.gz -> 603_0001.nii.gz
# Renamed image: 224_0000.nii.gz -> 604_0001.nii.gz
# Renamed mask:  224_0000.nii.gz -> 604_0001.nii.gz
# Renamed image: 225_0000.nii.gz -> 605_0001.nii.gz
# Renamed mask:  225_0000.nii.gz -> 605_0001.nii.gz
# Renamed image: 226_0000.nii.gz -> 606_0001.nii.gz
# Renamed mask:  226_0000.nii.gz -> 606_0001.nii.gz
# Renamed image: 227_0000.nii.gz -> 607_0001.nii.gz
# Renamed mask:  227_0000.nii.gz -> 607_0001.nii.gz
# Renamed image: 228_0000.nii.gz -> 608_0001.nii.gz
# Renamed mask:  228_0000.nii.gz -> 608_0001.nii.gz
# Renamed image: 229_0000.nii.gz -> 609_0001.nii.gz
# Renamed mask:  229_0000.nii.gz -> 609_0001.nii.gz
# Renamed image: 23_0000.nii.gz -> 610_0001.nii.gz
# Renamed mask:  23_0000.nii.gz -> 610_0001.nii.gz
# Renamed image: 231_0000.nii.gz -> 611_0001.nii.gz
# Renamed mask:  231_0000.nii.gz -> 611_0001.nii.gz
# Renamed image: 232_0000.nii.gz -> 612_0001.nii.gz
# Renamed mask:  232_0000.nii.gz -> 612_0001.nii.gz
# Renamed image: 233_0000.nii.gz -> 613_0001.nii.gz
# Renamed mask:  233_0000.nii.gz -> 613_0001.nii.gz
# Renamed image: 234_0000.nii.gz -> 614_0001.nii.gz
# Renamed mask:  234_0000.nii.gz -> 614_0001.nii.gz
# Renamed image: 236_0000.nii.gz -> 615_0001.nii.gz
# Renamed mask:  236_0000.nii.gz -> 615_0001.nii.gz
# Renamed image: 237_0000.nii.gz -> 616_0001.nii.gz
# Renamed mask:  237_0000.nii.gz -> 616_0001.nii.gz
# Renamed image: 239_0000.nii.gz -> 617_0001.nii.gz
# Renamed mask:  239_0000.nii.gz -> 617_0001.nii.gz
# Renamed image: 24_0000.nii.gz -> 618_0001.nii.gz
# Renamed mask:  24_0000.nii.gz -> 618_0001.nii.gz
# Renamed image: 241_0000.nii.gz -> 619_0001.nii.gz
# Renamed mask:  241_0000.nii.gz -> 619_0001.nii.gz
# Renamed image: 242_0000.nii.gz -> 620_0001.nii.gz
# Renamed mask:  242_0000.nii.gz -> 620_0001.nii.gz
# Renamed image: 243_0000.nii.gz -> 621_0001.nii.gz
# Renamed mask:  243_0000.nii.gz -> 621_0001.nii.gz
# Renamed image: 244_0000.nii.gz -> 622_0001.nii.gz
# Renamed mask:  244_0000.nii.gz -> 622_0001.nii.gz
# Renamed image: 245_0000.nii.gz -> 623_0001.nii.gz
# Renamed mask:  245_0000.nii.gz -> 623_0001.nii.gz
# Renamed image: 249_0000.nii.gz -> 624_0001.nii.gz
# Renamed mask:  249_0000.nii.gz -> 624_0001.nii.gz
# Renamed image: 25_0000.nii.gz -> 625_0001.nii.gz
# Renamed mask:  25_0000.nii.gz -> 625_0001.nii.gz
# Renamed image: 250_0000.nii.gz -> 626_0001.nii.gz
# Renamed mask:  250_0000.nii.gz -> 626_0001.nii.gz
# Renamed image: 251_0000.nii.gz -> 627_0001.nii.gz
# Renamed mask:  251_0000.nii.gz -> 627_0001.nii.gz
# Renamed image: 252_0000.nii.gz -> 628_0001.nii.gz
# Renamed mask:  252_0000.nii.gz -> 628_0001.nii.gz
# Renamed image: 253_0000.nii.gz -> 629_0001.nii.gz
# Renamed mask:  253_0000.nii.gz -> 629_0001.nii.gz
# Renamed image: 254_0000.nii.gz -> 630_0001.nii.gz
# Renamed mask:  254_0000.nii.gz -> 630_0001.nii.gz
# Renamed image: 255_0000.nii.gz -> 631_0001.nii.gz
# Renamed mask:  255_0000.nii.gz -> 631_0001.nii.gz
# Renamed image: 256_0000.nii.gz -> 632_0001.nii.gz
# Renamed mask:  256_0000.nii.gz -> 632_0001.nii.gz
# Renamed image: 257_0000.nii.gz -> 633_0001.nii.gz
# Renamed mask:  257_0000.nii.gz -> 633_0001.nii.gz
# Renamed image: 28_0000.nii.gz -> 634_0001.nii.gz
# Renamed mask:  28_0000.nii.gz -> 634_0001.nii.gz
# Renamed image: 29_0000.nii.gz -> 635_0001.nii.gz
# Renamed mask:  29_0000.nii.gz -> 635_0001.nii.gz
# Renamed image: 3_0000.nii.gz -> 636_0001.nii.gz
# Renamed mask:  3_0000.nii.gz -> 636_0001.nii.gz
# Renamed image: 30_0000.nii.gz -> 637_0001.nii.gz
# Renamed mask:  30_0000.nii.gz -> 637_0001.nii.gz
# Renamed image: 31_0000.nii.gz -> 638_0001.nii.gz
# Renamed mask:  31_0000.nii.gz -> 638_0001.nii.gz
# Renamed image: 32_0000.nii.gz -> 639_0001.nii.gz
# Renamed mask:  32_0000.nii.gz -> 639_0001.nii.gz
# Renamed image: 33_0000.nii.gz -> 640_0001.nii.gz
# Renamed mask:  33_0000.nii.gz -> 640_0001.nii.gz
# Renamed image: 34_0000.nii.gz -> 641_0001.nii.gz
# Renamed mask:  34_0000.nii.gz -> 641_0001.nii.gz
# Renamed image: 35_0000.nii.gz -> 642_0001.nii.gz
# Renamed mask:  35_0000.nii.gz -> 642_0001.nii.gz
# Renamed image: 36_0000.nii.gz -> 643_0001.nii.gz
# Renamed mask:  36_0000.nii.gz -> 643_0001.nii.gz
# Renamed image: 37_0000.nii.gz -> 644_0001.nii.gz
# Renamed mask:  37_0000.nii.gz -> 644_0001.nii.gz
# Renamed image: 38_0000.nii.gz -> 645_0001.nii.gz
# Renamed mask:  38_0000.nii.gz -> 645_0001.nii.gz
# Renamed image: 39_0000.nii.gz -> 646_0001.nii.gz
# Renamed mask:  39_0000.nii.gz -> 646_0001.nii.gz
# Renamed image: 4_0000.nii.gz -> 647_0001.nii.gz
# Renamed mask:  4_0000.nii.gz -> 647_0001.nii.gz
# Renamed image: 40_0000.nii.gz -> 648_0001.nii.gz
# Renamed mask:  40_0000.nii.gz -> 648_0001.nii.gz
# Renamed image: 44_0000.nii.gz -> 649_0001.nii.gz
# Renamed mask:  44_0000.nii.gz -> 649_0001.nii.gz
# Renamed image: 45_0000.nii.gz -> 650_0001.nii.gz
# Renamed mask:  45_0000.nii.gz -> 650_0001.nii.gz
# Renamed image: 47_0000.nii.gz -> 651_0001.nii.gz
# Renamed mask:  47_0000.nii.gz -> 651_0001.nii.gz
# Renamed image: 48_0000.nii.gz -> 652_0001.nii.gz
# Renamed mask:  48_0000.nii.gz -> 652_0001.nii.gz
# Renamed image: 5_0000.nii.gz -> 653_0001.nii.gz
# Renamed mask:  5_0000.nii.gz -> 653_0001.nii.gz
# Renamed image: 50_0000.nii.gz -> 654_0001.nii.gz
# Renamed mask:  50_0000.nii.gz -> 654_0001.nii.gz
# Renamed image: 51_0000.nii.gz -> 655_0001.nii.gz
# Renamed mask:  51_0000.nii.gz -> 655_0001.nii.gz
# Renamed image: 52_0000.nii.gz -> 656_0001.nii.gz
# Renamed mask:  52_0000.nii.gz -> 656_0001.nii.gz
# Renamed image: 53_0000.nii.gz -> 657_0001.nii.gz
# Renamed mask:  53_0000.nii.gz -> 657_0001.nii.gz
# Renamed image: 55_0000.nii.gz -> 658_0001.nii.gz
# Renamed mask:  55_0000.nii.gz -> 658_0001.nii.gz
# Renamed image: 56_0000.nii.gz -> 659_0001.nii.gz
# Renamed mask:  56_0000.nii.gz -> 659_0001.nii.gz
# Renamed image: 57_0000.nii.gz -> 660_0001.nii.gz
# Renamed mask:  57_0000.nii.gz -> 660_0001.nii.gz
# Renamed image: 58_0000.nii.gz -> 661_0001.nii.gz
# Renamed mask:  58_0000.nii.gz -> 661_0001.nii.gz
# Renamed image: 59_0000.nii.gz -> 662_0001.nii.gz
# Renamed mask:  59_0000.nii.gz -> 662_0001.nii.gz
# Renamed image: 60_0000.nii.gz -> 663_0001.nii.gz
# Renamed mask:  60_0000.nii.gz -> 663_0001.nii.gz
# Renamed image: 61_0000.nii.gz -> 664_0001.nii.gz
# Renamed mask:  61_0000.nii.gz -> 664_0001.nii.gz
# Renamed image: 62_0000.nii.gz -> 665_0001.nii.gz
# Renamed mask:  62_0000.nii.gz -> 665_0001.nii.gz
# Renamed image: 63_0000.nii.gz -> 666_0001.nii.gz
# Renamed mask:  63_0000.nii.gz -> 666_0001.nii.gz
# Renamed image: 64_0000.nii.gz -> 667_0001.nii.gz
# Renamed mask:  64_0000.nii.gz -> 667_0001.nii.gz
# Renamed image: 65_0000.nii.gz -> 668_0001.nii.gz
# Renamed mask:  65_0000.nii.gz -> 668_0001.nii.gz
# Renamed image: 66_0000.nii.gz -> 669_0001.nii.gz
# Renamed mask:  66_0000.nii.gz -> 669_0001.nii.gz
# Renamed image: 67_0000.nii.gz -> 670_0001.nii.gz
# Renamed mask:  67_0000.nii.gz -> 670_0001.nii.gz
# Renamed image: 68_0000.nii.gz -> 671_0001.nii.gz
# Renamed mask:  68_0000.nii.gz -> 671_0001.nii.gz
# Renamed image: 69_0000.nii.gz -> 672_0001.nii.gz
# Renamed mask:  69_0000.nii.gz -> 672_0001.nii.gz
# Renamed image: 7_0000.nii.gz -> 673_0001.nii.gz
# Renamed mask:  7_0000.nii.gz -> 673_0001.nii.gz
# Renamed image: 71_0000.nii.gz -> 674_0001.nii.gz
# Renamed mask:  71_0000.nii.gz -> 674_0001.nii.gz
# Renamed image: 72_0000.nii.gz -> 675_0001.nii.gz
# Renamed mask:  72_0000.nii.gz -> 675_0001.nii.gz
# Renamed image: 73_0000.nii.gz -> 676_0001.nii.gz
# Renamed mask:  73_0000.nii.gz -> 676_0001.nii.gz
# Renamed image: 74_0000.nii.gz -> 677_0001.nii.gz
# Renamed mask:  74_0000.nii.gz -> 677_0001.nii.gz
# Renamed image: 75_0000.nii.gz -> 678_0001.nii.gz
# Renamed mask:  75_0000.nii.gz -> 678_0001.nii.gz
# Renamed image: 77_0000.nii.gz -> 679_0001.nii.gz
# Renamed mask:  77_0000.nii.gz -> 679_0001.nii.gz
# Renamed image: 78_0000.nii.gz -> 680_0001.nii.gz
# Renamed mask:  78_0000.nii.gz -> 680_0001.nii.gz
# Renamed image: 8_0000.nii.gz -> 681_0001.nii.gz
# Renamed mask:  8_0000.nii.gz -> 681_0001.nii.gz
# Renamed image: 80_0000.nii.gz -> 682_0001.nii.gz
# Renamed mask:  80_0000.nii.gz -> 682_0001.nii.gz
# Renamed image: 81_0000.nii.gz -> 683_0001.nii.gz
# Renamed mask:  81_0000.nii.gz -> 683_0001.nii.gz
# Renamed image: 82_0000.nii.gz -> 684_0001.nii.gz
# Renamed mask:  82_0000.nii.gz -> 684_0001.nii.gz
# Renamed image: 83_0000.nii.gz -> 685_0001.nii.gz
# Renamed mask:  83_0000.nii.gz -> 685_0001.nii.gz
# Renamed image: 85_0000.nii.gz -> 686_0001.nii.gz
# Renamed mask:  85_0000.nii.gz -> 686_0001.nii.gz
# Renamed image: 86_0000.nii.gz -> 687_0001.nii.gz
# Renamed mask:  86_0000.nii.gz -> 687_0001.nii.gz
# Renamed image: 87_0000.nii.gz -> 688_0001.nii.gz
# Renamed mask:  87_0000.nii.gz -> 688_0001.nii.gz
# Renamed image: 88_0000.nii.gz -> 689_0001.nii.gz
# Renamed mask:  88_0000.nii.gz -> 689_0001.nii.gz
# Renamed image: 9_0000.nii.gz -> 690_0001.nii.gz
# Renamed mask:  9_0000.nii.gz -> 690_0001.nii.gz
# Renamed image: 90_0000.nii.gz -> 691_0001.nii.gz
# Renamed mask:  90_0000.nii.gz -> 691_0001.nii.gz
# Renamed image: 93_0000.nii.gz -> 692_0001.nii.gz
# Renamed mask:  93_0000.nii.gz -> 692_0001.nii.gz
# Renamed image: 94_0000.nii.gz -> 693_0001.nii.gz
# Renamed mask:  94_0000.nii.gz -> 693_0001.nii.gz
# Renamed image: 95_0000.nii.gz -> 694_0001.nii.gz
# Renamed mask:  95_0000.nii.gz -> 694_0001.nii.gz
# Renamed image: 96_0000.nii.gz -> 695_0001.nii.gz
# Renamed mask:  96_0000.nii.gz -> 695_0001.nii.gz
# Renamed image: 98_0000.nii.gz -> 696_0001.nii.gz
# Renamed mask:  98_0000.nii.gz -> 696_0001.nii.gz
#
# Finished renaming. Renamed 196 pairs of files.
# WARNING: The renaming function is commented out by default. Please read the script, set your paths, and uncomment 'rename_files_v2(...)' to run.
# It is highly recommended to test this script on a *copy* of your data first to prevent accidental data loss.
