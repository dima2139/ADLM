# %%
import os
import SimpleITK as sitk
import shutil

# %%
# Input .mha image folder (SPIDER dataset)
input_dir = "C:/ADLM/Datasets/SPIDER_FULL_FINAL/10159290/T2_masks"
#"C:/ADLM/Datasets/Dataset015_SPIDER/images/images"
#input_dir = "C:/ADLM/Datasets/Dataset015_SPIDER/masks/masks"
#output_imagesTr = "C:/ADLM/Datasets/SPIDER_Original/10159290/imagesTr"
output_labelsTr = "C:/ADLM/Datasets/SPIDER_FULL_FINAL/10159290/T2_masks_nii.gz" # Optional

# %%
# Map modality name to nnUNet index
modality_map = {
    "t1": "0000",
    "t2": "0001"
}

os.makedirs(output_labelsTr, exist_ok=True)

# Loop through all .mha files and convert + rename
for file in os.listdir(input_dir):
    if file.endswith(".mha"):
        # Example: 1_t1.mha → 1_0000.nii.gz
        base = file.replace(".mha", "")  # '1_t1'
        case_id_str, modality = base.split("_")  # '1', 't1'
        case_id = f"{int(case_id_str)}"  
        modality_idx = modality_map.get(modality.lower())

        if modality_idx is None:
            print(f"Skipping unknown modality in file: {file}")
            continue

        # Read MHA and convert to NIfTI
        img = sitk.ReadImage(os.path.join(input_dir, file))
        out_path = os.path.join(output_labelsTr, f"{case_id}_{modality_idx}.nii.gz") # change here
        sitk.WriteImage(img, out_path)
        print(f"Converted and saved: {file} -> {case_id}_{modality_idx}.nii.gz")
# Out:
# Converted and saved: 100_t2.mha -> 100_0001.nii.gz
# Converted and saved: 101_t2.mha -> 101_0001.nii.gz
# Converted and saved: 104_t2.mha -> 104_0001.nii.gz
# Converted and saved: 105_t2.mha -> 105_0001.nii.gz
# Converted and saved: 106_t2.mha -> 106_0001.nii.gz
# Converted and saved: 107_t2.mha -> 107_0001.nii.gz
# Converted and saved: 108_t2.mha -> 108_0001.nii.gz
# Converted and saved: 109_t2.mha -> 109_0001.nii.gz
# Converted and saved: 10_t2.mha -> 10_0001.nii.gz
# Converted and saved: 110_t2.mha -> 110_0001.nii.gz
# Converted and saved: 112_t2.mha -> 112_0001.nii.gz
# Converted and saved: 113_t2.mha -> 113_0001.nii.gz
# Converted and saved: 115_t2.mha -> 115_0001.nii.gz
# Converted and saved: 116_t2.mha -> 116_0001.nii.gz
# Converted and saved: 117_t2.mha -> 117_0001.nii.gz
# Converted and saved: 118_t2.mha -> 118_0001.nii.gz
# Converted and saved: 11_t2.mha -> 11_0001.nii.gz
# Converted and saved: 120_t2.mha -> 120_0001.nii.gz
# Converted and saved: 121_t2.mha -> 121_0001.nii.gz
# Converted and saved: 122_t2.mha -> 122_0001.nii.gz
# Converted and saved: 123_t2.mha -> 123_0001.nii.gz
# Converted and saved: 124_t2.mha -> 124_0001.nii.gz
# Converted and saved: 125_t2.mha -> 125_0001.nii.gz
# Converted and saved: 127_t2.mha -> 127_0001.nii.gz
# Converted and saved: 129_t2.mha -> 129_0001.nii.gz
# Converted and saved: 12_t2.mha -> 12_0001.nii.gz
# Converted and saved: 130_t2.mha -> 130_0001.nii.gz
# Converted and saved: 131_t2.mha -> 131_0001.nii.gz
# Converted and saved: 133_t2.mha -> 133_0001.nii.gz
# Converted and saved: 134_t2.mha -> 134_0001.nii.gz
# Converted and saved: 136_t2.mha -> 136_0001.nii.gz
# Converted and saved: 137_t2.mha -> 137_0001.nii.gz
# Converted and saved: 138_t2.mha -> 138_0001.nii.gz
# Converted and saved: 13_t2.mha -> 13_0001.nii.gz
# Converted and saved: 140_t2.mha -> 140_0001.nii.gz
# Converted and saved: 142_t2.mha -> 142_0001.nii.gz
# Converted and saved: 143_t2.mha -> 143_0001.nii.gz
# Converted and saved: 144_t2.mha -> 144_0001.nii.gz
# Converted and saved: 145_t2.mha -> 145_0001.nii.gz
# Converted and saved: 146_t2.mha -> 146_0001.nii.gz
# Converted and saved: 147_t2.mha -> 147_0001.nii.gz
# Converted and saved: 149_t2.mha -> 149_0001.nii.gz
# Converted and saved: 151_t2.mha -> 151_0001.nii.gz
# Converted and saved: 152_t2.mha -> 152_0001.nii.gz
# Converted and saved: 154_t2.mha -> 154_0001.nii.gz
# Converted and saved: 155_t2.mha -> 155_0001.nii.gz
# Converted and saved: 156_t2.mha -> 156_0001.nii.gz
# Converted and saved: 159_t2.mha -> 159_0001.nii.gz
# Converted and saved: 15_t2.mha -> 15_0001.nii.gz
# Converted and saved: 160_t2.mha -> 160_0001.nii.gz
# Converted and saved: 161_t2.mha -> 161_0001.nii.gz
# Converted and saved: 162_t2.mha -> 162_0001.nii.gz
# Converted and saved: 163_t2.mha -> 163_0001.nii.gz
# Converted and saved: 165_t2.mha -> 165_0001.nii.gz
# Converted and saved: 166_t2.mha -> 166_0001.nii.gz
# Converted and saved: 167_t2.mha -> 167_0001.nii.gz
# Converted and saved: 168_t2.mha -> 168_0001.nii.gz
# Converted and saved: 169_t2.mha -> 169_0001.nii.gz
# Converted and saved: 16_t2.mha -> 16_0001.nii.gz
# Converted and saved: 170_t2.mha -> 170_0001.nii.gz
# Converted and saved: 171_t2.mha -> 171_0001.nii.gz
# Converted and saved: 172_t2.mha -> 172_0001.nii.gz
# Converted and saved: 173_t2.mha -> 173_0001.nii.gz
# Converted and saved: 174_t2.mha -> 174_0001.nii.gz
# Converted and saved: 175_t2.mha -> 175_0001.nii.gz
# Converted and saved: 177_t2.mha -> 177_0001.nii.gz
# Converted and saved: 179_t2.mha -> 179_0001.nii.gz
# Converted and saved: 17_t2.mha -> 17_0001.nii.gz
# Converted and saved: 181_t2.mha -> 181_0001.nii.gz
# Converted and saved: 182_t2.mha -> 182_0001.nii.gz
# Converted and saved: 183_t2.mha -> 183_0001.nii.gz
# Converted and saved: 184_t2.mha -> 184_0001.nii.gz
# Converted and saved: 185_t2.mha -> 185_0001.nii.gz
# Converted and saved: 186_t2.mha -> 186_0001.nii.gz
# Converted and saved: 187_t2.mha -> 187_0001.nii.gz
# Converted and saved: 188_t2.mha -> 188_0001.nii.gz
# Converted and saved: 189_t2.mha -> 189_0001.nii.gz
# Converted and saved: 18_t2.mha -> 18_0001.nii.gz
# Converted and saved: 190_t2.mha -> 190_0001.nii.gz
# Converted and saved: 191_t2.mha -> 191_0001.nii.gz
# Converted and saved: 192_t2.mha -> 192_0001.nii.gz
# Converted and saved: 193_t2.mha -> 193_0001.nii.gz
# Converted and saved: 195_t2.mha -> 195_0001.nii.gz
# Converted and saved: 196_t2.mha -> 196_0001.nii.gz
# Converted and saved: 197_t2.mha -> 197_0001.nii.gz
# Converted and saved: 198_t2.mha -> 198_0001.nii.gz
# Converted and saved: 19_t2.mha -> 19_0001.nii.gz
# Converted and saved: 1_t2.mha -> 1_0001.nii.gz
# Converted and saved: 200_t2.mha -> 200_0001.nii.gz
# Converted and saved: 201_t2.mha -> 201_0001.nii.gz
# Converted and saved: 202_t2.mha -> 202_0001.nii.gz
# Converted and saved: 203_t2.mha -> 203_0001.nii.gz
# Converted and saved: 204_t2.mha -> 204_0001.nii.gz
# Converted and saved: 205_t2.mha -> 205_0001.nii.gz
# Converted and saved: 207_t2.mha -> 207_0001.nii.gz
# Converted and saved: 208_t2.mha -> 208_0001.nii.gz
# Converted and saved: 209_t2.mha -> 209_0001.nii.gz
# Converted and saved: 20_t2.mha -> 20_0001.nii.gz
# Converted and saved: 210_t2.mha -> 210_0001.nii.gz
# Converted and saved: 212_t2.mha -> 212_0001.nii.gz
# Converted and saved: 213_t2.mha -> 213_0001.nii.gz
# Converted and saved: 214_t2.mha -> 214_0001.nii.gz
# Converted and saved: 215_t2.mha -> 215_0001.nii.gz
# Converted and saved: 217_t2.mha -> 217_0001.nii.gz
# Converted and saved: 218_t2.mha -> 218_0001.nii.gz
# Converted and saved: 21_t2.mha -> 21_0001.nii.gz
# Converted and saved: 220_t2.mha -> 220_0001.nii.gz
# Converted and saved: 221_t2.mha -> 221_0001.nii.gz
# Converted and saved: 222_t2.mha -> 222_0001.nii.gz
# Converted and saved: 223_t2.mha -> 223_0001.nii.gz
# Converted and saved: 224_t2.mha -> 224_0001.nii.gz
# Converted and saved: 225_t2.mha -> 225_0001.nii.gz
# Converted and saved: 226_t2.mha -> 226_0001.nii.gz
# Converted and saved: 227_t2.mha -> 227_0001.nii.gz
# Converted and saved: 228_t2.mha -> 228_0001.nii.gz
# Converted and saved: 229_t2.mha -> 229_0001.nii.gz
# Converted and saved: 22_t2.mha -> 22_0001.nii.gz
# Converted and saved: 231_t2.mha -> 231_0001.nii.gz
# Converted and saved: 232_t2.mha -> 232_0001.nii.gz
# Converted and saved: 233_t2.mha -> 233_0001.nii.gz
# Converted and saved: 234_t2.mha -> 234_0001.nii.gz
# Converted and saved: 236_t2.mha -> 236_0001.nii.gz
# Converted and saved: 237_t2.mha -> 237_0001.nii.gz
# Converted and saved: 239_t2.mha -> 239_0001.nii.gz
# Converted and saved: 23_t2.mha -> 23_0001.nii.gz
# Converted and saved: 241_t2.mha -> 241_0001.nii.gz
# Converted and saved: 242_t2.mha -> 242_0001.nii.gz
# Converted and saved: 243_t2.mha -> 243_0001.nii.gz
# Converted and saved: 244_t2.mha -> 244_0001.nii.gz
# Converted and saved: 245_t2.mha -> 245_0001.nii.gz
# Converted and saved: 246_t2.mha -> 246_0001.nii.gz
# Converted and saved: 249_t2.mha -> 249_0001.nii.gz
# Converted and saved: 24_t2.mha -> 24_0001.nii.gz
# Converted and saved: 250_t2.mha -> 250_0001.nii.gz
# Converted and saved: 251_t2.mha -> 251_0001.nii.gz
# Converted and saved: 252_t2.mha -> 252_0001.nii.gz
# Converted and saved: 253_t2.mha -> 253_0001.nii.gz
# Converted and saved: 254_t2.mha -> 254_0001.nii.gz
# Converted and saved: 255_t2.mha -> 255_0001.nii.gz
# Converted and saved: 256_t2.mha -> 256_0001.nii.gz
# Converted and saved: 257_t2.mha -> 257_0001.nii.gz
# Converted and saved: 25_t2.mha -> 25_0001.nii.gz
# Converted and saved: 28_t2.mha -> 28_0001.nii.gz
# Converted and saved: 29_t2.mha -> 29_0001.nii.gz
# Converted and saved: 2_t2.mha -> 2_0001.nii.gz
# Converted and saved: 30_t2.mha -> 30_0001.nii.gz
# Converted and saved: 31_t2.mha -> 31_0001.nii.gz
# Converted and saved: 32_t2.mha -> 32_0001.nii.gz
# Converted and saved: 33_t2.mha -> 33_0001.nii.gz
# Converted and saved: 34_t2.mha -> 34_0001.nii.gz
# Converted and saved: 35_t2.mha -> 35_0001.nii.gz
# Converted and saved: 36_t2.mha -> 36_0001.nii.gz
# Converted and saved: 37_t2.mha -> 37_0001.nii.gz
# Converted and saved: 38_t2.mha -> 38_0001.nii.gz
# Converted and saved: 39_t2.mha -> 39_0001.nii.gz
# Converted and saved: 3_t2.mha -> 3_0001.nii.gz
# Converted and saved: 40_t2.mha -> 40_0001.nii.gz
# Converted and saved: 42_t2.mha -> 42_0001.nii.gz
# Converted and saved: 44_t2.mha -> 44_0001.nii.gz
# Converted and saved: 45_t2.mha -> 45_0001.nii.gz
# Converted and saved: 47_t2.mha -> 47_0001.nii.gz
# Converted and saved: 48_t2.mha -> 48_0001.nii.gz
# Converted and saved: 4_t2.mha -> 4_0001.nii.gz
# Converted and saved: 50_t2.mha -> 50_0001.nii.gz
# Converted and saved: 51_t2.mha -> 51_0001.nii.gz
# Converted and saved: 52_t2.mha -> 52_0001.nii.gz
# Converted and saved: 53_t2.mha -> 53_0001.nii.gz
# Converted and saved: 55_t2.mha -> 55_0001.nii.gz
# Converted and saved: 56_t2.mha -> 56_0001.nii.gz
# Converted and saved: 57_t2.mha -> 57_0001.nii.gz
# Converted and saved: 58_t2.mha -> 58_0001.nii.gz
# Converted and saved: 59_t2.mha -> 59_0001.nii.gz
# Converted and saved: 5_t2.mha -> 5_0001.nii.gz
# Converted and saved: 60_t2.mha -> 60_0001.nii.gz
# Converted and saved: 61_t2.mha -> 61_0001.nii.gz
# Converted and saved: 62_t2.mha -> 62_0001.nii.gz
# Converted and saved: 63_t2.mha -> 63_0001.nii.gz
# Converted and saved: 64_t2.mha -> 64_0001.nii.gz
# Converted and saved: 65_t2.mha -> 65_0001.nii.gz
# Converted and saved: 66_t2.mha -> 66_0001.nii.gz
# Converted and saved: 67_t2.mha -> 67_0001.nii.gz
# Converted and saved: 68_t2.mha -> 68_0001.nii.gz
# Converted and saved: 69_t2.mha -> 69_0001.nii.gz
# Converted and saved: 6_t2.mha -> 6_0001.nii.gz
# Converted and saved: 71_t2.mha -> 71_0001.nii.gz
# Converted and saved: 73_t2.mha -> 73_0001.nii.gz
# Converted and saved: 74_t2.mha -> 74_0001.nii.gz
# Converted and saved: 75_t2.mha -> 75_0001.nii.gz
# Converted and saved: 78_t2.mha -> 78_0001.nii.gz
# Converted and saved: 7_t2.mha -> 7_0001.nii.gz
# Converted and saved: 80_t2.mha -> 80_0001.nii.gz
# Converted and saved: 81_t2.mha -> 81_0001.nii.gz
# Converted and saved: 82_t2.mha -> 82_0001.nii.gz
# Converted and saved: 83_t2.mha -> 83_0001.nii.gz
# Converted and saved: 85_t2.mha -> 85_0001.nii.gz
# Converted and saved: 86_t2.mha -> 86_0001.nii.gz
# Converted and saved: 87_t2.mha -> 87_0001.nii.gz
# Converted and saved: 88_t2.mha -> 88_0001.nii.gz
# Converted and saved: 89_t2.mha -> 89_0001.nii.gz
# Converted and saved: 8_t2.mha -> 8_0001.nii.gz
# Converted and saved: 90_t2.mha -> 90_0001.nii.gz
# Converted and saved: 91_t2.mha -> 91_0001.nii.gz
# Converted and saved: 93_t2.mha -> 93_0001.nii.gz
# Converted and saved: 94_t2.mha -> 94_0001.nii.gz
# Converted and saved: 95_t2.mha -> 95_0001.nii.gz
# Converted and saved: 96_t2.mha -> 96_0001.nii.gz
# Converted and saved: 97_t2.mha -> 97_0001.nii.gz
# Converted and saved: 98_t2.mha -> 98_0001.nii.gz
# Converted and saved: 99_t2.mha -> 99_0001.nii.gz
# Converted and saved: 9_t2.mha -> 9_0001.nii.gz
